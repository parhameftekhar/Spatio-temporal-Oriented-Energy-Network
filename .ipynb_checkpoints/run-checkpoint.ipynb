# %%
import time
import tensorflow as tf
import numpy as np
import sys
import input_data, os
import configure as cfg
import init_SOE_NET as init_net
import SOE_Net_model_full as model

# %%
################################################################################################
#""" INITIALIZE SOE-NET PARAMETERS """
################################################################################################
tf.reset_default_graph()

orientations = np.array(init_net.initOrientations (cfg.ORIENTATIONS,cfg.SPEEDS,cfg.NUM_DIRECTIONS), dtype=np.float32)
                
#print("[INFO] INIT", orientations,"STANDARD ORIENTATIONS...")
basis = init_net.initSeparableFilters('basis', cfg.FILTER_TAPS, filter_type="G3")

basis_2d = init_net.initSeparableFilters_SO('basis2d', cfg.FILTER_TAPS, filter_type="G2")
#print("[INFO] INIT", basis,"3D SEPARABLE FILTERS...")
#print("[INFO] INIT", basis_2d,"2D SEPARABLE FILTERS...")

biases_soe = init_net.initBiases('bias', 0)
              
#print("[INFO] INIT", biases_soe,"SEPARABLE FILTERS...")

# %%
################################################################################################
#""" READ THE INPUT DATA """
################################################################################################

# TEST DATA
tiny_batch_size = 1 # to extract features for one video at a time for this example code purposes
vid_path = "/local/riemann1/home/parham/DTDB/frames_train/" + "clips.txt"
print("[INFO] READING IN TEST DATA FROM :", vid_path)
test_clips, test_start_indices, test_labels = input_data.load_clips_labels(vid_path)
num_test_clips = len(test_clips)
print("[INFO] TOTAL NUMBER OF TESTING VIDEO CLIPS :", num_test_clips)
#raw_input('Press enter to continue ... ')
TEST_ITERS = int(float(num_test_clips)/float(tiny_batch_size))
print("[INFO] NUMPBER OF ITERATIONS TO GO THROUGH TEST SET IS: ", TEST_ITERS)
# Out:
# ('[INFO] READING IN TEST DATA FROM :', '/local/riemann1/home/parham/DTDB/frames_train/clips.txt')
# [Info] loading lists...
# /local/riemann1/home/parham/DTDB/frames_train/class14_5690
# 0
# 14
# /local/riemann1/home/parham/DTDB/frames_train/class3_990
# 0
# 3
# /local/riemann1/home/parham/DTDB/frames_train/class4_1432
# 0
# 4
# /local/riemann1/home/parham/DTDB/frames_train/class0_212
# 0
# 0
# /local/riemann1/home/parham/DTDB/frames_train/class14_5429
# 0
# 14
# /local/riemann1/home/parham/DTDB/frames_train/class2_741
# 0
# 2
# /local/riemann1/home/parham/DTDB/frames_train/class5_1645
# 0
# 5
# /local/riemann1/home/parham/DTDB/frames_train/class10_3691
# 0
# 10
# /local/riemann1/home/parham/DTDB/frames_train/class1_666
# 0
# 1
# /local/riemann1/home/parham/DTDB/frames_train/class9_3156
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class17_6812
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class5_1780
# 0
# 5
# /local/riemann1/home/parham/DTDB/frames_train/class14_5445
# 0
# 14
# /local/riemann1/home/parham/DTDB/frames_train/class16_6762
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class17_6798
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class16_6498
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class2_724
# 0
# 2
# /local/riemann1/home/parham/DTDB/frames_train/class8_2866
# 0
# 8
# /local/riemann1/home/parham/DTDB/frames_train/class9_3416
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class1_516
# 0
# 1
# /local/riemann1/home/parham/DTDB/frames_train/class7_2462
# 0
# 7
# /local/riemann1/home/parham/DTDB/frames_train/class10_3558
# 0
# 10
# /local/riemann1/home/parham/DTDB/frames_train/class17_6796
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class1_407
# 0
# 1
# /local/riemann1/home/parham/DTDB/frames_train/class16_6445
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class4_1450
# 0
# 4
# /local/riemann1/home/parham/DTDB/frames_train/class8_3010
# 0
# 8
# /local/riemann1/home/parham/DTDB/frames_train/class16_6575
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class3_1066
# 0
# 3
# /local/riemann1/home/parham/DTDB/frames_train/class14_5689
# 0
# 14
# /local/riemann1/home/parham/DTDB/frames_train/class7_2232
# 0
# 7
# /local/riemann1/home/parham/DTDB/frames_train/class1_456
# 0
# 1
# /local/riemann1/home/parham/DTDB/frames_train/class12_4718
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class15_6106
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/class16_6564
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class13_5173
# 0
# 13
# /local/riemann1/home/parham/DTDB/frames_train/class4_1535
# 0
# 4
# /local/riemann1/home/parham/DTDB/frames_train/class8_2602
# 0
# 8
# /local/riemann1/home/parham/DTDB/frames_train/class14_5574
# 0
# 14
# /local/riemann1/home/parham/DTDB/frames_train/class11_4140
# 0
# 11
# /local/riemann1/home/parham/DTDB/frames_train/class17_7023
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class10_3717
# 0
# 10
# /local/riemann1/home/parham/DTDB/frames_train/class7_2545
# 0
# 7
# /local/riemann1/home/parham/DTDB/frames_train/class14_5514
# 0
# 14
# /local/riemann1/home/parham/DTDB/frames_train/class9_3400
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class4_1518
# 0
# 4
# /local/riemann1/home/parham/DTDB/frames_train/class12_4460
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class1_582
# 0
# 1
# /local/riemann1/home/parham/DTDB/frames_train/class6_2008
# 0
# 6
# /local/riemann1/home/parham/DTDB/frames_train/class17_6960
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class8_2772
# 0
# 8
# /local/riemann1/home/parham/DTDB/frames_train/class1_573
# 0
# 1
# /local/riemann1/home/parham/DTDB/frames_train/class7_2418
# 0
# 7
# /local/riemann1/home/parham/DTDB/frames_train/class16_6542
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class15_5934
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/class12_4338
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class10_3681
# 0
# 10
# /local/riemann1/home/parham/DTDB/frames_train/class10_3855
# 0
# 10
# /local/riemann1/home/parham/DTDB/frames_train/class15_5845
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/class12_4691
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class17_6931
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class15_6321
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/class12_4761
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class14_5340
# 0
# 14
# /local/riemann1/home/parham/DTDB/frames_train/class10_3841
# 0
# 10
# /local/riemann1/home/parham/DTDB/frames_train/class2_726
# 0
# 2
# /local/riemann1/home/parham/DTDB/frames_train/class9_3329
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class2_779
# 0
# 2
# /local/riemann1/home/parham/DTDB/frames_train/class7_2197
# 0
# 7
# /local/riemann1/home/parham/DTDB/frames_train/class16_6474
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class17_6810
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class0_325
# 0
# 0
# /local/riemann1/home/parham/DTDB/frames_train/class6_2108
# 0
# 6
# /local/riemann1/home/parham/DTDB/frames_train/class13_4853
# 0
# 13
# /local/riemann1/home/parham/DTDB/frames_train/class2_904
# 0
# 2
# /local/riemann1/home/parham/DTDB/frames_train/class1_537
# 0
# 1
# /local/riemann1/home/parham/DTDB/frames_train/class7_2165
# 0
# 7
# /local/riemann1/home/parham/DTDB/frames_train/class16_6582
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class12_4627
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class11_4137
# 0
# 11
# /local/riemann1/home/parham/DTDB/frames_train/class16_6436
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class12_4675
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class17_7006
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class14_5322
# 0
# 14
# /local/riemann1/home/parham/DTDB/frames_train/class8_2956
# 0
# 8
# /local/riemann1/home/parham/DTDB/frames_train/class9_3187
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class8_2630
# 0
# 8
# /local/riemann1/home/parham/DTDB/frames_train/class2_952
# 0
# 2
# /local/riemann1/home/parham/DTDB/frames_train/class12_4688
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class13_4992
# 0
# 13
# /local/riemann1/home/parham/DTDB/frames_train/class17_6884
# 0
# 17
# /local/riemann1/home/parham/DTDB/frames_train/class16_6670
# 0
# 16
# /local/riemann1/home/parham/DTDB/frames_train/class10_3612
# 0
# 10
# /local/riemann1/home/parham/DTDB/frames_train/class4_1352
# 0
# 4
# /local/riemann1/home/parham/DTDB/frames_train/class9_3275
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class15_5999
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/class7_2148
# 0
# 7
# /local/riemann1/home/parham/DTDB/frames_train/class12_4693
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class7_2534
# 0
# 7
# /local/riemann1/home/parham/DTDB/frames_train/class15_6330
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/class2_728
# 0
# 2
# /local/riemann1/home/parham/DTDB/frames_train/class9_3107
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class12_4766
# 0
# 12
# /local/riemann1/home/parham/DTDB/frames_train/class8_2997
# 0
# 8
# /local/riemann1/home/parham/DTDB/frames_train/class15_5797
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/class6_1857
# 0
# 6
# /local/riemann1/home/parham/DTDB/frames_train/class13_5071
# 0
# 13
# /local/riemann1/home/parham/DTDB/frames_train/class9_3327
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class5_1737
# 0
# 5
# /local/riemann1/home/parham/DTDB/frames_train/class9_3471
# 0
# 9
# /local/riemann1/home/parham/DTDB/frames_train/class15_5758
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/
# 0
# 13
# /local/riemann1/home/parham/DTDB/frames_train/class13_5137
# 0
# 13
# /local/riemann1/home/parham/DTDB/frames_train/class15_6348
# 0
# 15
# /local/riemann1/home/parham/DTDB/frames_train/clips.txt
# 0
# clips.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5ffb38ae3934> in <module>()
#       7 vid_path = "/local/riemann1/home/parham/DTDB/frames_train/" + "clips.txt"
#       8 print("[INFO] READING IN TEST DATA FROM :", vid_path)
# ----> 9 test_clips, test_start_indices, test_labels = input_data.load_clips_labels(vid_path)
#      10 num_test_clips = len(test_clips)
#      11 print("[INFO] TOTAL NUMBER OF TESTING VIDEO CLIPS :", num_test_clips)
#
# /home/parham/SOE_NET/input_data.py in load_clips_labels(path_lst)
#      39         clips.append( filename)
#      40         start_indices.append(int(frame_start))
# ---> 41         labels.append(int(cat_id))
#      42     return clips, start_indices, labels
#      43
#
# ValueError: invalid literal for int() with base 10: 'clips.txt'

# %%
################################################################################################
#""" PREPARE DATA FOR TENSORFLOW """
################################################################################################
if cfg.CROP:
    input_shape   = [tiny_batch_size, cfg.TIME_S, cfg.IMG_S, cfg.IMG_S, 1]
else:
    input_shape   = [tiny_batch_size, cfg.TIME_S, cfg.IMG_RAW_H, cfg.IMG_RAW_W, 1]
 
batch_videos_ph  = tf.placeholder(tf.float32, shape=input_shape, name="batch_videos")
print(batch_videos_ph)
# Out:
# Tensor("batch_videos:0", shape=(1, 42, 128, 171, 1), dtype=float32)

# %%
################################################################################################   
#""" BUILD THE TENSORFLOW GRAPH """
################################################################################################
# example 4: Extract SOE_Net features
soenet = model.SOE_Net(batch_videos_ph, basis, orientations, biases_soe)

# example 2: Extract MSOE features
msoe = model.get_MSOE(batch_videos_ph, basis, orientations, biases_soe)


init = tf.global_variables_initializer()
sess = tf.Session()
# initialize the non-trained variables
sess.run(init)

test_indices = np.arange(num_test_clips)
test_start_idx = 0

SOE_NET_FEAT = []
tic = time.time()
for iter in range(TEST_ITERS):
    """ LOAD VIDEOS ONE BATCH AT A TIME """
    test_batch_clips, test_batch_indices, test_batch_labels, test_stop_idx = input_data.select_batch (test_clips,test_start_indices, test_labels, test_start_idx, test_indices, tiny_batch_size)
    print(test_batch_indices)
    batch_videos=input_data.load_frames(test_batch_clips,test_batch_indices,crop=False)
    print("size of clips in batch is : ", np.shape(batch_videos))
    print("stop_idx is : ", test_stop_idx)
    test_start_idx = test_stop_idx
    
    #tic = time.time()
    soenet_feat = sess.run(soenet, feed_dict={batch_videos_ph: batch_videos}) 
    #print("time to run through one mini-batch is: ", time.time()-tic)
    
    """ EXAMPLE: SAVE THE RESULTS FOR FURTHER USE (IN ANOTHER APPLICATION FOR EXAMPLE)"""
    for b in range(soenet_feat.shape[0]):
        # TODO: INSTEAD OF APPENDING ACCUMULATE RESULTS OBTAINED BY APPLYING GSP
        SOE_NET_FEAT.append(soenet_feat[b,:])

SOE_NET_FEAT = np.concatenate(SOE_NET_FEAT, axis=0)   

#save results to npy file

# feat_path = savepath + vid_name + ".npy"
# extracted_features = {'soe': SOE_FEAT, 'msoe': MSOE_FEAT, 'SO': SO_FEAT, 'soe_net':SOE_NET_FEAT,\
#                       'msoe1': MSOE1,'msoe2': MSOE2,'msoe3': MSOE3,'msoe4': MSOE4,\
#                       'so1':SO1,'so2':SO2,'so3':SO3,'so4':SO4}
# np.save(feat_path, extracted_features)
print("time to run through one mini-batch is: ", time.time()-tic)

print('Done')
# Out:
# Tensor("Layer1/strided_slice_60:0", shape=(1, 42, 128, 171, 20), dtype=float32)
# Tensor("Layer2/Conv3D_1800:0", shape=(1, 42, 128, 171, 40), dtype=float32)
# Tensor("Layer3/Conv3D_3600:0", shape=(1, 21, 64, 86, 80), dtype=float32)
# [0]
# ('size of clips in batch is : ', (1, 42, 128, 171, 1))
# ('stop_idx is : ', 1)
# ('time to run through one mini-batch is: ', 30.976766109466553)
# Done

# %% [markdown]
# # New Run

# %%
import time
import tensorflow as tf
import numpy as np
import sys
import input_data, os
import configure as cfg
import init_SOE_NET as init_net
import SOE_Net_model_full as model


################################################################################################
#""" INITIALIZE SOE-NET PARAMETERS """
################################################################################################
tf.reset_default_graph()

orientations = np.array(init_net.initOrientations (cfg.ORIENTATIONS,cfg.SPEEDS,cfg.NUM_DIRECTIONS), dtype=np.float32)
                
#print("[INFO] INIT", orientations,"STANDARD ORIENTATIONS...")
basis = init_net.initSeparableFilters('basis', cfg.FILTER_TAPS, filter_type="G3")

basis_2d = init_net.initSeparableFilters_SO('basis2d', cfg.FILTER_TAPS, filter_type="G2")
#print("[INFO] INIT", basis,"3D SEPARABLE FILTERS...")
#print("[INFO] INIT", basis_2d,"2D SEPARABLE FILTERS...")

biases_soe = init_net.initBiases('bias', 0)
              
#print("[INFO] INIT", biases_soe,"SEPARABLE FILTERS...")

################################################################################################
#""" READ THE INPUT DATA """
################################################################################################

# TEST DATA
tiny_batch_size = 1 # to extract features for one video at a time for this example code purposes
vid_path = "/home/eftekhar/Documents/DTDB_NEW/TEST/" + "NEW_TEST_clips.txt"
print("[INFO] READING IN TEST DATA FROM :", vid_path)
test_clips, test_start_indices, test_labels = input_data.load_clips_labels(vid_path)
num_test_clips = len(test_clips)
print("[INFO] TOTAL NUMBER OF TESTING VIDEO CLIPS :", num_test_clips)
#raw_input('Press enter to continue ... ')
TEST_ITERS = int(float(num_test_clips)/float(tiny_batch_size))
print("[INFO] NUMPBER OF ITERATIONS TO GO THROUGH TEST SET IS: ", TEST_ITERS)

################################################################################################
#""" PREPARE DATA FOR TENSORFLOW """
################################################################################################
if cfg.CROP:
    input_shape   = [tiny_batch_size, cfg.TIME_S, cfg.IMG_S, cfg.IMG_S, 1]
else:
    input_shape   = [tiny_batch_size, cfg.TIME_S, cfg.IMG_RAW_H, cfg.IMG_RAW_W, 1]
 
batch_videos_ph  = tf.placeholder(tf.float32, shape=input_shape, name="batch_videos")
print(batch_videos_ph)

################################################################################################   
#""" BUILD THE TENSORFLOW GRAPH """
################################################################################################
# example 4: Extract SOE_Net features
soenet = model.SOE_Net(batch_videos_ph, basis, orientations, biases_soe)

# example 2: Extract MSOE features
msoe = model.get_MSOE(batch_videos_ph, basis, orientations, biases_soe)


init = tf.global_variables_initializer()
sess = tf.Session()
# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# initialize the non-trained variables
sess.run(init)

test_indices = np.arange(num_test_clips)
test_start_idx = 0

SOE_NET_FEAT = []
tic = time.time()
excluded_vid = []
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_1082417/2758422924.py:14: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /home/eftekhar/Project/init_SOE_NET.py:103: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# [INFO] READING IN TEST DATA FROM : /home/eftekhar/Documents/DTDB_NEW/TEST/NEW_TEST_clips.txt
# [Info] loading lists...
# [INFO] TOTAL NUMBER OF TESTING VIDEO CLIPS : 18723
# [INFO] NUMPBER OF ITERATIONS TO GO THROUGH TEST SET IS:  18723
# WARNING:tensorflow:From /tmp/ipykernel_1082417/2758422924.py:52: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("batch_videos:0", shape=(1, 42, 128, 171, 1), dtype=float32)
# Tensor("Layer1/strided_slice_60:0", shape=(1, 42, 128, 171, 20), dtype=float32) Tensor("Layer1/strided_slice_60:0", shape=(1, 42, 128, 171, 20), dtype=float32)
# Tensor("Layer2/strided_slice_1200:0", shape=(1, 42, 128, 171, 400), dtype=float32) Tensor("Layer2/Conv3D_1800:0", shape=(1, 42, 128, 171, 40), dtype=float32)
# Tensor("Layer3/strided_slice_2400:0", shape=(1, 21, 64, 86, 800), dtype=float32) Tensor("Layer3/Conv3D_3600:0", shape=(1, 21, 64, 86, 80), dtype=float32)
# Tensor("Layer4/strided_slice_4800:0", shape=(1, 7, 22, 29, 1600), dtype=float32) Tensor("Layer4/Conv3D_7200:0", shape=(1, 7, 22, 29, 160), dtype=float32)
# WARNING:tensorflow:From /tmp/ipykernel_1082417/2758422924.py:65: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_1082417/2758422924.py:66: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# 2022-04-19 21:11:27.641089: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-04-19 21:11:27.685503: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro P6000 major: 6 minor: 1 memoryClockRate(GHz): 1.645
# pciBusID: 0000:65:00.0
# 2022-04-19 21:11:27.685658: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-04-19 21:11:27.686546: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-04-19 21:11:27.687326: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-04-19 21:11:27.687527: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-04-19 21:11:27.688539: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-04-19 21:11:27.689294: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-04-19 21:11:27.691752: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-04-19 21:11:27.692030: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-04-19 21:11:27.692999: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2022-04-19 21:11:27.715088: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3699850000 Hz
# 2022-04-19 21:11:27.715781: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x560b7f611230 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-04-19 21:11:27.715810: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-04-19 21:11:27.716130: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro P6000 major: 6 minor: 1 memoryClockRate(GHz): 1.645
# pciBusID: 0000:65:00.0
# 2022-04-19 21:11:27.716173: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-04-19 21:11:27.716186: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-04-19 21:11:27.716196: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-04-19 21:11:27.716207: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-04-19 21:11:27.716217: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-04-19 21:11:27.716227: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-04-19 21:11:27.716238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-04-19 21:11:27.716531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-04-19 21:11:27.716567: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-04-19 21:11:27.766818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-19 21:11:27.766840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-04-19 21:11:27.766844: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-04-19 21:11:27.767241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22636 MB memory) -> physical GPU (device: 0, name: Quadro P6000, pci bus id: 0000:65:00.0, compute capability: 6.1)
# 2022-04-19 21:11:27.770438: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x560b870c7e50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-04-19 21:11:27.770478: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro P6000, Compute Capability 6.1

# %%
for iter in range(TEST_ITERS):
    """ LOAD VIDEOS ONE BATCH AT A TIME """
    test_batch_clips, test_batch_indices, test_batch_labels, test_stop_idx = input_data.select_batch(test_clips,test_start_indices, test_labels, test_start_idx, test_indices, tiny_batch_size)
    print(test_batch_clips)
    print(test_batch_indices)
    try:
        batch_videos=input_data.load_frames(test_batch_clips,test_batch_indices,crop=False)
    except:
        print("hi")
        excluded_vid.append(test_batch_clips[0])
        test_start_idx = test_stop_idx
        continue 
    print("size of clips in batch is : ", np.shape(batch_videos))
    print("stop_idx is : ", test_stop_idx)
    test_start_idx = test_stop_idx
    print("This is iteration number:{}".format(iter))
    #tic = time.time()
    soenet_feat = sess.run(soenet, feed_dict={batch_videos_ph: batch_videos}) 
    #print("time to run through one mini-batch is: ", time.time()-tic)
    print(soenet_feat.shape)
    """ EXAMPLE: SAVE THE RESULTS FOR FURTHER USE (IN ANOTHER APPLICATION FOR EXAMPLE)"""
    for b in range(soenet_feat.shape[0]):
        # TODO: INSTEAD OF APPENDING ACCUMULATE RESULTS OBTAINED BY APPLYING GSP
        SOE_NET_FEAT.append(soenet_feat)

SOE_NET_FEAT = np.concatenate(SOE_NET_FEAT, axis=0)   
print(SOE_NET_FEAT.shape)
# save results to npy file

feat_path = "./" + "features_test.npy"
extracted_features = {'soe_net':SOE_NET_FEAT}
np.save(feat_path, extracted_features)
print("time to run through one mini-batch is: ", time.time()-tic)
print(excluded_vid)
print('Done')
# Out:
# ['/home/eftekhar/Documents/DTDB_NEW/TEST/Chaotic_motion/Chaotic_motion_g1_c1/']
# [1]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  1
# This is iteration number:0
# 2022-04-19 21:11:59.787233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-04-19 21:12:00.892624: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# (1, 3200)
# ['/home/eftekhar/Documents/DTDB_NEW/TEST/Chaotic_motion/Chaotic_motion_g1_c1/']
# [37]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  2
# This is iteration number:1
# (1, 3200)
# ['/home/eftekhar/Documents/DTDB_NEW/TEST/Chaotic_motion/Chaotic_motion_g1_c1/']
# [73]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  3
# This is iteration number:2
# (1, 3200)
# ['/home/eftekhar/Documents/DTDB_NEW/TEST/Chaotic_motion/Chaotic_motion_g1_c1/']
# [109]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  4
# This is iteration number:3
# (1, 3200)
# ['/home/eftekhar/Documents/DTDB_NEW/TEST/Chaotic_motion/Chaotic_motion_g1_c1/']
# [145]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  5
# This is iteration number:4
# (1, 3200)
# ['/home/eftekhar/Documents/DTDB_NEW/TEST/Chaotic_motion/Chaotic_motion_g1_c1/']
# [181]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  6
# This is iteration number:5
# (1, 3200)
# ['/home/eftekhar/Documents/DTDB_NEW/TEST/Chaotic_motion/Chaotic_motion_g1_c2/']
# [1]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  7
# This is iteration number:6
# (1, 3200)
# ['/home/eftekhar/Documents/DTDB_NEW/TEST/Chaotic_motion/Chaotic_motion_g1_c2/']
# [37]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  8
# This is iteration number:7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1082417/3812900655.py in <module>
#      16     print("This is iteration number:{}".format(iter))
#      17     #tic = time.time()
# ---> 18     soenet_feat = sess.run(soenet, feed_dict={batch_videos_ph: batch_videos})
#      19     #print("time to run through one mini-batch is: ", time.time()-tic)
#      20     print(soenet_feat.shape)
#
# ~/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
line = "/home/eftekhar/Documents/DTDB_NEW/TEST/Wavy_motion/Wavy_motion_g3_c9/ 181 17"
cat_id, frame_start, filename = line[::-1].split(' ', 2)
filename, frame_start, cat_id = filename[::-1], frame_start[::-1], cat_id[::-1]

# %%
filename
# Out:
# '/home/eftekhar/Documents/DTDB_NEW/TEST/Wavy_motion/Wavy_motion_g3_c9/'

# %%
import time
import tensorflow as tf
import numpy as np
import sys
import input_data, os
import configure as cfg
import init_SOE_NET as init_net
import SOE_Net_model_full as model


################################################################################################
#""" INITIALIZE SOE-NET PARAMETERS """
################################################################################################
tf.reset_default_graph()

orientations = np.array(init_net.initOrientations (cfg.ORIENTATIONS,cfg.SPEEDS,cfg.NUM_DIRECTIONS), dtype=np.float32)
                
#print("[INFO] INIT", orientations,"STANDARD ORIENTATIONS...")
basis = init_net.initSeparableFilters('basis', cfg.FILTER_TAPS, filter_type="G3")

basis_2d = init_net.initSeparableFilters_SO('basis2d', cfg.FILTER_TAPS, filter_type="G2")
#print("[INFO] INIT", basis,"3D SEPARABLE FILTERS...")
#print("[INFO] INIT", basis_2d,"2D SEPARABLE FILTERS...")

biases_soe = init_net.initBiases('bias', 0)
              
#print("[INFO] INIT", biases_soe,"SEPARABLE FILTERS...")

################################################################################################
#""" READ THE INPUT DATA """
################################################################################################

# TEST DATA
tiny_batch_size = 1 # to extract features for one video at a time for this example code purposes
vid_path = "/home/eftekhar/Documents/Databases/AVDT_backup/Frames/clips.txt"
print("[INFO] READING IN TEST DATA FROM :", vid_path)
test_clips, test_start_indices, test_labels = input_data.load_clips_labels(vid_path)
num_test_clips = len(test_clips)
print("[INFO] TOTAL NUMBER OF TESTING VIDEO CLIPS :", num_test_clips)
#raw_input('Press enter to continue ... ')
TEST_ITERS = int(float(num_test_clips)/float(tiny_batch_size))
print("[INFO] NUMPBER OF ITERATIONS TO GO THROUGH TEST SET IS: ", TEST_ITERS)

################################################################################################
#""" PREPARE DATA FOR TENSORFLOW """
################################################################################################
if cfg.CROP:
    input_shape   = [tiny_batch_size, cfg.TIME_S, cfg.IMG_S, cfg.IMG_S, 1]
else:
    input_shape   = [tiny_batch_size, cfg.TIME_S, cfg.IMG_RAW_H, cfg.IMG_RAW_W, 1]
 
batch_videos_ph  = tf.placeholder(tf.float32, shape=input_shape, name="batch_videos")
print(batch_videos_ph)

################################################################################################   
#""" BUILD THE TENSORFLOW GRAPH """
################################################################################################
# example 4: Extract SOE_Net features
soenet = model.SOE_Net(batch_videos_ph, basis, orientations, biases_soe)

# example 2: Extract MSOE features
msoe = model.get_MSOE(batch_videos_ph, basis, orientations, biases_soe)


init = tf.global_variables_initializer()
sess = tf.Session()
# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# initialize the non-trained variables
sess.run(init)

test_indices = np.arange(num_test_clips)
test_start_idx = 0

SOE_NET_FEAT = []
tic = time.time()
excluded_vid = []
for iter in range(TEST_ITERS):
    """ LOAD VIDEOS ONE BATCH AT A TIME """
    test_batch_clips, test_batch_indices, test_batch_labels, test_stop_idx = input_data.select_batch(test_clips,test_start_indices, test_labels, test_start_idx, test_indices, tiny_batch_size)
    print(test_batch_clips)
    print(test_batch_indices)
    try:
        batch_videos=input_data.load_frames(test_batch_clips,test_batch_indices,crop=False)
    except:
        excluded_vid.append(test_batch_clips[0])
        test_start_idx = test_stop_idx
        continue 
    print("size of clips in batch is : ", np.shape(batch_videos))
    print("stop_idx is : ", test_stop_idx)
    test_start_idx = test_stop_idx
    print("This is iteration number:{}".format(iter))
    #tic = time.time()
    soenet_feat = sess.run(soenet, feed_dict={batch_videos_ph: batch_videos}) 
    #print("time to run through one mini-batch is: ", time.time()-tic)
    print(soenet_feat.shape)
    """ EXAMPLE: SAVE THE RESULTS FOR FURTHER USE (IN ANOTHER APPLICATION FOR EXAMPLE)"""
    for b in range(soenet_feat.shape[0]):
        # TODO: INSTEAD OF APPENDING ACCUMULATE RESULTS OBTAINED BY APPLYING GSP
        SOE_NET_FEAT.append(soenet_feat)
    break
SOE_NET_FEAT = np.concatenate(SOE_NET_FEAT, axis=0)   
print(SOE_NET_FEAT.shape)
# save results to npy file

# feat_path = "./video_features/" + "features_test.npy"
# extracted_features = {'soe_net':SOE_NET_FEAT}
# np.save(feat_path, extracted_features)
# print("time to run through one mini-batch is: ", time.time()-tic)
# print(excluded_vid)
# print('Done')
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_3907140/241215616.py:14: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /home/eftekhar/Project/init_SOE_NET.py:103: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# [INFO] READING IN TEST DATA FROM : /home/eftekhar/Documents/Databases/AVDT_backup/Frames/clips.txt
# [Info] loading lists...
# [INFO] TOTAL NUMBER OF TESTING VIDEO CLIPS : 20113
# [INFO] NUMPBER OF ITERATIONS TO GO THROUGH TEST SET IS:  20113
# WARNING:tensorflow:From /tmp/ipykernel_3907140/241215616.py:52: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("batch_videos:0", shape=(1, 42, 128, 171, 1), dtype=float32)
# (1, 42, 128, 171, 20)
# (1, 42, 128, 171, 40)
# (1, 21, 64, 86, 80)
# (1, 7, 22, 29, 160)
# (1, 3200)
# WARNING:tensorflow:From /tmp/ipykernel_3907140/241215616.py:65: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_3907140/241215616.py:66: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# 2022-09-02 11:47:30.268333: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-09-02 11:47:30.290835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro P6000 major: 6 minor: 1 memoryClockRate(GHz): 1.645
# pciBusID: 0000:65:00.0
# 2022-09-02 11:47:30.291032: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-09-02 11:47:30.292332: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-09-02 11:47:30.293469: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-09-02 11:47:30.293751: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-09-02 11:47:30.295274: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-09-02 11:47:30.296446: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-09-02 11:47:30.299814: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-09-02 11:47:30.300144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-09-02 11:47:30.300841: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2022-09-02 11:47:30.323125: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3699850000 Hz
# 2022-09-02 11:47:30.323758: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a34b61be20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-09-02 11:47:30.323782: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-09-02 11:47:30.324114: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro P6000 major: 6 minor: 1 memoryClockRate(GHz): 1.645
# pciBusID: 0000:65:00.0
# 2022-09-02 11:47:30.324173: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-09-02 11:47:30.324188: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-09-02 11:47:30.324201: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-09-02 11:47:30.324217: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-09-02 11:47:30.324229: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-09-02 11:47:30.324239: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-09-02 11:47:30.324250: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-09-02 11:47:30.324539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-09-02 11:47:30.324587: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-09-02 11:47:30.398515: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-02 11:47:30.398545: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-09-02 11:47:30.398555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-09-02 11:47:30.398986: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 21592 MB memory) -> physical GPU (device: 0, name: Quadro P6000, pci bus id: 0000:65:00.0, compute capability: 6.1)
# 2022-09-02 11:47:30.400423: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a36a306270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-09-02 11:47:30.400439: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro P6000, Compute Capability 6.1
# ['/home/eftekhar/Documents/Databases/AVDT_backup/Frames/flag/flag_115']
# [0]
# size of clips in batch is :  (1, 42, 128, 171, 1)
# stop_idx is :  1
# This is iteration number:0
# 2022-09-02 11:48:00.161145: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-09-02 11:48:00.972836: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# (1, 3200)
# (1, 3200)

# %%
feat_path = "./video_features/" + "features_test.npy"
np.save(feat_path, SOE_NET_FEAT)
print("time to run through one mini-batch is: ", time.time()-tic)
print(excluded_vid)
print('Done')
# Out:
# time to run through one mini-batch is:  271.0198349952698
# []
# Done
