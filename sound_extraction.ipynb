# %%
import os
import moviepy.editor as mp

# %%
PATH_VIDEO = "/home/eftekhar/Documents/Databases/AVDT_backup/videos"
PATH_AUDIO = "/home/eftekhar/Documents/Databases/AVDT_backup/Audios"
# for d in os.listdir(PATH_VIDEO):
#     os.makedirs(os.path.join(PATH_AUDIO, d))

# %%
error = []
for vid in os.listdir(os.path.join(PATH_VIDEO, "flock_of_sheep")):
    file_name = os.path.join(PATH_VIDEO, "flock_of_sheep", vid)
    try:
        clip = mp.VideoFileClip(file_name)
        clip.audio.write_audiofile(r"{}.mp3".format(os.path.join(PATH_AUDIO, "flock_of_sheep", vid.split(".")[0])))
    except:
        error.append(file_name)
# Out:
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flock_of_sheep/sheep_112.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flock_of_sheep/sheep_105.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flock_of_sheep/sheep_142.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flock_of_sheep/sheep_143.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flock_of_sheep/sheep_146.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flock_of_sheep/sheep_154.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flock_of_sheep/sheep_200.mp3
# MoviePy - Done.
# ...

# %%
error
# Out:
# ['/',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/h',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/o',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/m',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/e',
#  '/',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/e',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/f',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/t',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/e',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/k',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/h',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/a',
#  '/home/eftekhar/Documents/Databases/AVDT_backup/videos/flock_of_sheep/r',
#  '/',
# ...

# %%
error = []
for d in os.listdir(PATH_VIDEO):
    for vid in os.listdir(os.path.join(PATH_VIDEO, d)):
        file_name = os.path.join(PATH_VIDEO, d, vid)
        try:
            clip = mp.VideoFileClip(file_name)
            clip.audio.write_audiofile(r"{}.mp3".format(os.path.join(PATH_AUDIO, d, vid.split(".")[0])))
        except:
            error.append(file_name)
# Out:
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_213.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_217.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_28.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_154.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_225.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_280.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_184.mp3
# MoviePy - Done.
# ...

# %%
for d in os.listdir(PATH_AUDIO):
    print(d, len(os.listdir(os.path.join(PATH_AUDIO, d))))
# Out:
# flag 310
# piano 300
# waterfall 235
# rushing river 190
# vegetation 301
# airshow 302
# fire 199
# rainfall 263
# running_train 200
# car_traffic 200
# firework 101
# keyboard_typing 206
# bee 107
# drumline 193
# wavy_water 192
# geyser_fountain 98
# school_of_fish 157
# applause 201
# string_orchestra 101

# %%
for d in os.listdir(PATH_VIDEO):
    print(d, len(os.listdir(os.path.join(PATH_AUDIO, d))))
# Out:
# flag 310
# piano 300
# waterfall 235
# rushing river 190
# vegetation 301
# airshow 302
# fire 199
# rainfall 263
# running_train 200
# car_traffic 200
# firework 101
# keyboard_typing 206
# bee 107
# drumline 193
# wavy_water 192
# geyser_fountain 98
# school_of_fish 157
# applause 201
# string_orchestra 101

# %% [markdown]
# # Minimum length of videos

# %%
import audio2numpy as a2n
import os
PATH_AUDIO = "/home/eftekhar/Documents/Databases/AVDT_backup/Audios"
length = []
for d in os.listdir(PATH_AUDIO):
    for vid in os.listdir(os.path.join(PATH_AUDIO, d)):
        audio_path = os.path.join(PATH_AUDIO, d, vid)
        x,sr=a2n.audio_from_file(audio_path)
        length.append((x.shape[0], audio_path))
    print(d)
# Out:
# flag
# piano
# waterfall
# rushing river
# vegetation
# airshow
# fire
# rainfall
# running_train
# car_traffic
# firework
# keyboard_typing
# bee
# drumline
# wavy_water
# geyser_fountain
# school_of_fish
# applause
# string_orchestra

# %%
length
# Out:
# [(293265,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_101.mp3'),
#  (298998,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_246.mp3'),
#  (403515,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_7.mp3'),
#  (313992,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_115.mp3'),
#  (294588,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_34.mp3'),
#  (353711,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_203.mp3'),
#  (274743,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_81.mp3'),
#  (415863,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_217.mp3'),
#  (305172,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_266.mp3'),
#  (426888,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_261.mp3'),
#  (327663,
# ...

# %%
list(filter(lambda x: x[0] < 2**17, length))
# Out:
# [(6615,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/flag/flag_228.mp3'),
#  (33075,
#   '/home/eftekhar/Documents/Databases/AVDT_backup/Audios/keyboard_typing/keyboard_129.mp3')]

# %%
6615

# %%
# Out:
# 4096

# %%
clip = mp.VideoFileClip("v.mp4")
clip.audio.write_audiofile(r"{}.mp3".format("a"))
# Out:
# MoviePy - Writing audio in a.mp3
# MoviePy - Done.

# %%
x,sr=a2n.audio_from_file("a1.mp3")

# %%
# Out:
# (2612224, 2)

# %% [markdown]
# # Sample rates

# %%
import audio2numpy as a2n
import os
import librosa
PATH_AUDIO = "/home/eftekhar/Documents/Databases/AVDT_backup/Audios"
length1 = []
length2 = []
for d in os.listdir(PATH_AUDIO):
    for vid in os.listdir(os.path.join(PATH_AUDIO, d)):
        audio_path = os.path.join(PATH_AUDIO, d, vid)
        y, sr = librosa.load(audio_path)
        length1.append((len(y), sr))
#         x,sr=a2n.audio_from_file(audio_path)
#         length2.append((len(x), sr))
#         length.append((sr, audio_path))
    print(d)
# Out:
# /home/eftekhar/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /home/eftekhar/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /home/eftekhar/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /home/eftekhar/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /home/eftekhar/anaconda3/envs/SOE_NET/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# ...

# %%
from util import highestPowerof2
set([highestPowerof2(l[0]) for l in length1])
# Out:
# {65536, 131072, 262144}

# %%
math.log2(65536)
# Out:
# 16.0

# %%
n = 4
print(length1[n][0])
print(length2[n][0])
# Out:
# 147294
# 294588

# %%
min([x[0] for x in length2])
# Out:
# 131859

# %%
2**12
# Out:
# 8192

# %%
from SOE_NET_1D import SOE_Net
import configure as cfg
import init_SOE_NET as init_net
import numpy as np
import tensorflow as tf
from SOE_NET_1D import conv1d
from util import highestPowerof2
import audio2numpy as a2n
import librosa
import matplotlib.pyplot as plt       
# from SOE_NET_1D import SC1D, TPR, FWR, DivNorm1d, GSP
import os
from util import bar_plot
import pickle


PATH_AUDIO = "/home/eftekhar/Documents/Databases/AVDT_backup/Audios"

# dic = {}
files = []
for d in os.listdir(PATH_AUDIO):
#     classes.append(d)
    audios = os.listdir(os.path.join(PATH_AUDIO, d))
#     m = min(100, len(audios))
    print(d)
    print(len(os.listdir(os.path.join(PATH_AUDIO, d))))
    for aud in os.listdir(os.path.join(PATH_AUDIO, d))[:100]:
        files.append(aud.split(".")[0])
#     dic[d] = files
#         audio_path = os.path.join(PATH_AUDIO, d, aud)
#         files.append(audio_path)
        # x,sr=a2n.audio_from_file(audio_path)
#         x, s = librosa.load(audio_path, sr=cfg.ORIGINAL_SAMPLING_RATE)
#         n = highestPowerof2(x.shape[0])
#         x = x[x.shape[0] // 2 - n // 2 : x.shape[0] // 2 + n // 2]
#         shapes.append(x.shape[0])
#         print(x.shape)
# Out:
# flag
# 100
# piano
# 100
# waterfall
# 100
# rushing river
# 100
# vegetation
# 100
# airshow
# 100
# fire
# 100
# rainfall
# 100
# running_train
# 100
# car_traffic
# 100
# firework
# 100
# keyboard_typing
# 100
# bee
# 100
# drumline
# 100
# wavy_water
# 100
# geyser_fountain
# 98
# school_of_fish
# 100
# applause
# 100
# flock_of_sheep
# 100
# string_orchestra
# 100

# %%
PATH_AUDIO = "/home/eftekhar/Documents/Databases/AVDT_backup/videos"
c=0
files2 = []
for d in os.listdir(PATH_AUDIO):
#     classes.append(d)
    audios = os.listdir(os.path.join(PATH_AUDIO, d))
#     m = min(100, len(audios))
    print(d)
    print(len(os.listdir(os.path.join(PATH_AUDIO, d))))
    for vid in os.listdir(os.path.join(PATH_AUDIO, d)):
        files2.append(vid.split(".")[0])
#         if vid.split(".")[0] in dic[d]:
#             c+=1
#         else:
#             os.remove(os.path.join(PATH_AUDIO, d, vid))
#             print(os.path.join(PATH_AUDIO, d, vid))
            
c
# Out:
# flag
# 100
# piano
# 100
# waterfall
# 100
# rushing river
# 100
# vegetation
# 100
# airshow
# 100
# fire
# 100
# rainfall
# 100
# running_train
# 100
# car_traffic
# 100
# firework
# 100
# keyboard_typing
# 100
# bee
# 100
# drumline
# 100
# wavy_water
# 100
# geyser_fountain
# 98
# school_of_fish
# 100
# applause
# 100
# flock_of_sheep
# 100
# string_orchestra
# 100
# 0

# %%
len(files2)
# Out:
# 1998

# %%
for key, value in dic.items():
    print(key)
    print(len(value))

# %%
for i in range(len(fire)):
    if fire[i] == fire[i+1]:
        print(fire[i])
        break
# Out:
# Bonefire_g1_c30

# %%
import os

PATH_AUDIO = "/home/eftekhar/Documents/Databases/AVDT_backup/Audios"
c=0
files2 = []
for d in os.listdir(PATH_AUDIO):
    audios = os.listdir(os.path.join(PATH_AUDIO, d))
    print(d)
    print(len(os.listdir(os.path.join(PATH_AUDIO, d))))
    for vid in os.listdir(os.path.join(PATH_AUDIO, d)):
        files2.append(vid.split(".")[0])
# Out:
# flag
# 100
# piano
# 100
# waterfall
# 100
# rushing river
# 100
# vegetation
# 100
# airshow
# 100
# fire
# 100
# rainfall
# 100
# running_train
# 100
# car_traffic
# 100
# firework
# 100
# keyboard_typing
# 100
# bee
# 100
# drumline
# 100
# wavy_water
# 100
# geyser_fountain
# 98
# school_of_fish
# 100
# applause
# 100
# flock_of_sheep
# 100
# string_orchestra
# 100
# 0

# %%
PATH_VIDEOS = "/home/eftekhar/Documents/Databases/AVDT_backup/videos/geyser_fountain"
# c=0
# for d in os.listdir(PATH_VIDEOS):
#     print(d)
#     print(len(os.listdir(os.path.join(PATH_VIDEOS, d))))
#     for vid in os.listdir(os.path.join(PATH_VIDEOS, d)):
#         if vid.split(".")[0] in files2:
#             c += 1 
# c

len(os.listdir(PATH_VIDEOS))
# Out:
# 100

# %%
os.listdir("/home/eftekhar/Documents/Databases/AVDT_backup")
# Out:
# ['Audios', 'videos']

# %%
# PATH = "/home/eftekhar/Documents/Databases/AVDT_backup/videos/geyser_fountain/geyser_fountain_207.mp4"
# OUT = "/home/eftekhar/Documents/Databases/AVDT_backup/Audios/geyser_fountain"
# clip = mp.VideoFileClip(PATH)
# clip.audio.write_audiofile("/home/eftekhar/Documents/Databases/AVDT_backup/Audios/geyser_fountain/geyser_fountain_207.mp3")
# Out:
# MoviePy - Writing audio in /home/eftekhar/Documents/Databases/AVDT_backup/Audios/geyser_fountain/geyser_fountain_207.mp3
# MoviePy - Done.

# %%
len(os.listdir(OUT))
# Out:
# 100
